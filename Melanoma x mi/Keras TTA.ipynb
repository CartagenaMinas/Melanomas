# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50V2

tf.__version__
# Out:
# '2.5.0'

# %%
# !git clone https://github.com/CartagenaMinas/Melanomas.git
# Out:
# fatal: destination path 'Melanomas' already exists and is not an empty directory.

# %%
import os
os.listdir("Melanomas")
# Out:
# ['Keras_baseline.ipynb', 'data', 'exploracion.ipynb', '.git']

# %%
PATH="Melanomas/data"
os.listdir(PATH)
# Out:
# ['jpeg224',
#  'test.csv',
#  'sample_submission.csv',
#  'train.csv',
#  'train_split.csv',
#  'val_split.csv',
#  'subset.csv']

# %%
import pandas as pd
train=pd.read_csv(f"{PATH}/subset.csv")
val=pd.read_csv(f"{PATH}/val_split.csv")
train.shape,val.shape
# Out:
# ((2220, 8), (10932, 8))

# %%
train.head()
# Out:
#      image_name  patient_id     sex  ...  diagnosis benign_malignant target
# 0  ISIC_0533349  IP_5208504  female  ...    unknown           benign      0
# 1  ISIC_8814612  IP_0414408    male  ...    unknown           benign      0
# 2  ISIC_6515241  IP_6245507    male  ...    unknown           benign      0
# 3  ISIC_5075261  IP_2117218    male  ...    unknown           benign      0
# 4  ISIC_2624460  IP_1969685    male  ...    unknown           benign      0
#
# [5 rows x 8 columns]

# %%
BATCH_SIZE = 64
AUTO = tf.data.experimental.AUTOTUNE

def decode(filename, label):
    img = tf.io.read_file(filename)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32)
    return img, label

def augment(img, label):
    # augmentation
    #img = tf.image.flip_left_right(img)
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    return img, label

def load_ds(df):
    options = tf.data.Options()
    options.experimental_deterministic = False
    imgs, labels = df["image_name"].values, df["target"].values
    imgs = [f'{PATH}/jpeg224/train/{img}.jpg' for img in imgs]
    ds = tf.data.Dataset.from_tensor_slices((imgs, labels))
    ds = ds.with_options(options)
    ds = ds.map(decode, num_parallel_calls=AUTO)
    #ds = ds.cache()
    ds = ds.map(augment, num_parallel_calls=AUTO)
    ds = ds.shuffle(2048)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTO)
    return ds

# %%
train_ds=load_ds(train)
val_ds=load_ds(val)

# %%
IMAGE_SIZE = (224, 224, 3)

encoder = ResNet50V2(
    include_top=False,
    input_shape=IMAGE_SIZE,
    weights='imagenet'
)
encoder.trainable = False

inputs = keras.Input(shape=IMAGE_SIZE)
x = keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)
x = encoder(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 224, 224, 3)       0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 7, 7, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.AUC(name="auc")]
)

# %%
filepath="./checkpoints/checkpoint"
cb=tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath,
    monitor="val_auc",
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode="max"
)

# %%
model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds,
    validation_steps=10,
    callbacks=[cb])
# Out:
# Epoch 1/10
# 35/35 [==============================] - 15s 308ms/step - loss: 0.1542 - auc: 0.3947 - val_loss: 0.1371 - val_auc: 0.5551
#
# Epoch 00001: val_auc improved from -inf to 0.55514, saving model to ./checkpoints/checkpoint
# Epoch 2/10
# 35/35 [==============================] - 12s 282ms/step - loss: 0.0979 - auc: 0.5504 - val_loss: 0.1263 - val_auc: 0.6137
#
# Epoch 00002: val_auc improved from 0.55514 to 0.61368, saving model to ./checkpoints/checkpoint
# Epoch 3/10
# 35/35 [==============================] - 12s 284ms/step - loss: 0.0845 - auc: 0.6997 - val_loss: 0.1202 - val_auc: 0.7395
#
# Epoch 00003: val_auc improved from 0.61368 to 0.73946, saving model to ./checkpoints/checkpoint
# Epoch 4/10
# 35/35 [==============================] - 12s 286ms/step - loss: 0.0772 - auc: 0.7867 - val_loss: 0.1025 - val_auc: 0.5923
#
# Epoch 00004: val_auc did not improve from 0.73946
# Epoch 5/10
# 35/35 [==============================] - 12s 282ms/step - loss: 0.0716 - auc: 0.8295 - val_loss: 0.1049 - val_auc: 0.7283
#
# Epoch 00005: val_auc did not improve from 0.73946
# Epoch 6/10
# 35/35 [==============================] - 11s 280ms/step - loss: 0.0661 - auc: 0.8889 - val_loss: 0.0919 - val_auc: 0.8148
#
# Epoch 00006: val_auc improved from 0.73946 to 0.81483, saving model to ./checkpoints/checkpoint
# Epoch 7/10
# 35/35 [==============================] - 12s 284ms/step - loss: 0.0645 - auc: 0.8996 - val_loss: 0.0771 - val_auc: 0.6124
#
# Epoch 00007: val_auc did not improve from 0.81483
# Epoch 8/10
# 35/35 [==============================] - 12s 288ms/step - loss: 0.0619 - auc: 0.9154 - val_loss: 0.1381 - val_auc: 0.6581
#
# Epoch 00008: val_auc did not improve from 0.81483
# Epoch 9/10
# 35/35 [==============================] - 11s 277ms/step - loss: 0.0614 - auc: 0.9152 - val_loss: 0.1117 - val_auc: 0.8150
#
# Epoch 00009: val_auc improved from 0.81483 to 0.81498, saving model to ./checkpoints/checkpoint
# Epoch 10/10
# 35/35 [==============================] - 11s 279ms/step - loss: 0.0593 - auc: 0.9198 - val_loss: 0.1108 - val_auc: 0.7350
#
# Epoch 00010: val_auc did not improve from 0.81498

# %%
#Cargar los Pesos
model.load_weights(filepath)
model.save("model.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
model.evaluate(val_ds)
# Out:
# 171/171 [==============================] - 32s 178ms/step - loss: 0.0777 - auc: 0.7895
# [0.07765401899814606, 0.7894809246063232]

# %%
m=tf.keras.metrics.AUC()
aucs=[]

for imgs, labels in val_ds:
  imgs_lr=tf.image.flip_left_right(imgs)
  imgs_ud=tf.image.flip_up_down(imgs)
  preds=(model.predict(imgs)+model.predict(imgs_lr)+model.predict(imgs_ud))/3
  _=m.update_state(labels,preds)#Calcula la metrica
  aucs.append(m.result().numpy())

# %%
import numpy as np

np.mean(aucs)
# Out:
# 0.7777581

# %%
test=pd.read_csv(f"{PATH}/test.csv")
test.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %%
BATCH_SIZE=256

def decode_test(name):
  img=tf.io.read_file(name)#lo lee en byts
  img=tf.image.decode_jpeg(img,channels=3)#lo carga como imagen
  img=tf.cast(img,tf.float32)#/255#cambia la presicion
  return img

def load_test_ds(df):
  imgs=df["image_name"].values#Creo una lista 
  imgs=[f"{PATH}/jpeg224/test/{name}.jpg" for name in imgs]#Creo una lista con mis rutas
  ds=tf.data.Dataset.from_tensor_slices(imgs)
  ds=ds.map(decode_test)
  ds=ds.batch(BATCH_SIZE)
  return ds

# %%
test_ds=load_test_ds(test)

# %%
preds = []

for imgs in test_ds:
  imgs_lr=tf.image.flip_left_right(imgs)
  imgs_ud=tf.image.flip_up_down(imgs)
  _preds=(model.predict(imgs)+model.predict(imgs_lr)+model.predict(imgs_ud))/3
  preds += _preds.ravel().tolist()

# %%
preds
# Out:
# [0.005456258077174425,
#  0.003947441000491381,
#  0.005934633780270815,
#  0.0004585131537169218,
#  0.0030168790835887194,
#  0.012647464871406555,
#  0.0033391450997442007,
#  0.20865564048290253,
#  0.009170307777822018,
#  0.012854748405516148,
#  0.011033720336854458,
#  0.0013582626124843955,
#  0.026287948712706566,
#  0.000691301713231951,
#  0.06317060440778732,
#  0.0050403159111738205,
#  0.0026162590365856886,
#  0.0011795168975368142,
#  0.04333004355430603,
#  0.15258543193340302,
#  0.018319470807909966,
#  0.0019559829961508512,
#  0.036599770188331604,
#  0.006841955706477165,
#  0.18828296661376953,
#  0.012596399523317814,
#  0.0009397279936820269,
#  0.003729534102603793,
#  0.004165541846305132,
#  0.0020914613269269466,
#  0.013763323426246643,
#  0.0015143383061513305,
#  0.11745921522378922,
#  0.043167468160390854,
#  0.044464025646448135,
#  0.0018778688972815871,
#  0.006840792950242758,
#  0.07051756978034973,
#  0.002778249094262719,
#  0.007330911699682474,
#  0.0022420065943151712,
#  0.08376555889844894,
#  0.08401497453451157,
#  0.0034296512603759766,
#  0.0015236936742439866,
#  0.06820990890264511,
#  0.023827137425541878,
#  0.007645258214324713,
#  0.0031063714995980263,
#  0.02558734081685543,
#  0.00928587932139635,
#  0.006551658734679222,
#  0.004591851029545069,
#  0.02849559485912323,
#  0.01536218449473381,
#  0.002539007691666484,
#  0.036810193210840225,
#  0.031873829662799835,
#  0.01244285423308611,
#  0.01682203821837902,
#  0.003535717725753784,
#  0.029349172487854958,
#  0.07471037656068802,
#  0.0035718504805117846,
#  0.020611444488167763,
#  0.16200096905231476,
#  0.03263715282082558,
#  0.009464225731790066,
#  0.0007477204198949039,
#  0.03353304788470268,
#  0.0011761129135265946,
#  0.08037400990724564,
#  0.00355496141128242,
#  0.005841206293553114,
#  0.004679231438785791,
#  0.004722972866147757,
#  0.00341166858561337,
#  0.0163651704788208,
#  0.015986433252692223,
#  0.003644822398200631,
#  0.005342585500329733,
#  0.0023336426820605993,
#  0.0026942298281937838,
#  0.0016102768713608384,
#  0.029428521171212196,
#  0.007271571084856987,
#  0.023740718141198158,
#  0.04552658274769783,
#  0.01840858720242977,
#  0.010094338096678257,
#  0.0022519207559525967,
#  0.005595988128334284,
#  0.010663256980478764,
#  0.007762361317873001,
#  0.0010217562085017562,
#  0.0857839584350586,
#  0.007936765439808369,
#  0.0008515443769283593,
#  0.0005114946397952735,
#  0.004580498207360506,
#  0.028275996446609497,
#  0.014828707091510296,
#  0.004536462482064962,
#  0.001246571191586554,
#  0.12048053741455078,
#  0.004249260760843754,
#  0.046156007796525955,
#  0.010591584257781506,
#  0.01582757942378521,
#  0.027371039614081383,
#  0.0027142539620399475,
#  0.001812572474591434,
#  0.005066124256700277,
#  0.0007360402960330248,
#  0.001155002973973751,
#  0.004654200281947851,
#  0.06708790361881256,
#  0.0005633661057800055,
#  0.007213016506284475,
#  0.08105812221765518,
#  0.016590658575296402,
#  0.006746448110789061,
#  0.0015332609182223678,
#  0.002152701374143362,
#  0.002998125972226262,
#  0.0012618951732292771,
#  0.017955852672457695,
#  0.007647048216313124,
#  0.001354884821921587,
#  0.019628027454018593,
#  0.011733338236808777,
#  0.025674114003777504,
#  0.008286037482321262,
#  0.005012342240661383,
#  0.0061482456512749195,
#  0.0006393057410605252,
#  0.009943501092493534,
#  0.007927363738417625,
#  0.0034482257906347513,
#  0.013936273753643036,
#  0.0015001725405454636,
#  0.03901704028248787,
#  0.0036729462444782257,
#  0.025535086169838905,
#  0.04708889126777649,
#  0.0474221408367157,
#  0.034731894731521606,
#  0.0013098795898258686,
#  0.004047940019518137,
#  0.05250204727053642,
#  0.0016039818292483687,
#  0.04008050635457039,
#  0.1830756664276123,
#  0.02267584390938282,
#  0.001730794203467667,
#  0.006080492865294218,
#  0.003647217294201255,
#  0.02377033419907093,
#  0.012294981628656387,
#  0.016525423154234886,
#  0.04673383757472038,
#  0.01671837456524372,
#  0.0019277437822893262,
#  0.04752777889370918,
#  0.11240337044000626,
#  0.004943299572914839,
#  0.14144888520240784,
#  0.02655377984046936,
#  0.0688447430729866,
#  0.005859992001205683,
#  0.0009704986587166786,
#  0.003249530913308263,
#  0.004987838212400675,
#  0.03726087883114815,
#  0.03220319375395775,
#  0.00854067225009203,
#  0.021275388076901436,
#  0.0034585713874548674,
#  0.0012108276132494211,
#  0.009854117408394814,
#  0.0005961268325336277,
#  0.023795753717422485,
#  0.004292976576834917,
#  0.009054065681993961,
#  0.05526646599173546,
#  0.0326601080596447,
#  0.003703698515892029,
#  0.003650094149634242,
#  0.01082619745284319,
#  0.09341835230588913,
#  0.04039913788437843,
#  0.014614406041800976,
#  0.12010771781206131,
#  0.028572574257850647,
#  0.019297529011964798,
#  0.006548732053488493,
#  0.01614057458937168,
#  0.013335607014596462,
#  0.004477882757782936,
#  0.008257112465798855,
#  0.0020577113609761,
#  0.03727731108665466,
#  0.006986390799283981,
#  0.007048388477414846,
#  0.028082525357604027,
#  0.00507538253441453,
#  0.0029737232252955437,
#  0.018677890300750732,
#  0.002249733079224825,
#  0.060520898550748825,
#  0.00754835968837142,
#  0.013887929730117321,
#  0.020506329834461212,
#  0.05496423318982124,
#  0.0006289785378612578,
#  0.018549485132098198,
#  0.013448226265609264,
#  ...]

# %%
submission=pd.DataFrame({
    "image_name":test["image_name"].values,"target":preds
})
submission.head()
# Out:
#      image_name    target
# 0  ISIC_0052060  0.005456
# 1  ISIC_0052349  0.003947
# 2  ISIC_0058510  0.005935
# 3  ISIC_0073313  0.000459
# 4  ISIC_0073502  0.003017

# %%
submission.to_csv("sumissionDA4.csv",index=False)
